# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
input_file = "./troop_movements10m.csv"
raw = pd.read_csv(input_file)

# %%
raw.head(5)
# Out:
#              timestamp  unit_id     unit_type  location_x  location_y  \
# 0  2023-06-13 17:33:18        1         at-st         2.0         8.0
# 1  2023-06-13 17:33:17        2  tie_silencer         4.0         4.0
# 2  2023-06-13 17:33:16        3         at-at         0.0         3.0
# 3  2023-06-13 17:33:15        4  tie_silencer         6.0         1.0
# 4  2023-06-13 17:33:14        5   tie_fighter         0.0         4.0
#
#    destination_x  destination_y    homeworld
# 0              1              1  Glee Anselm
# 1              0              1    Trandosha
# 2              6              1     Corellia
# 3              6              9        Shili
# 4              9              6   Muunilinst

# %%
data = raw.copy()

# %%
data["unit_type"].replace("invalid_unit", "unknown", inplace = True)
data.ffill(inplace = True)

# %% [markdown]
# %pip install pyarrow
# %pip install fastparquet

# %%
data.to_parquet('troop_movements10m.parquet')

# %%
troop_movements10m = pd.read_parquet('./troop_movements10m.parquet')

# %%
troop_movements10m.head()
# Out:
#              timestamp  unit_id     unit_type  location_x  location_y  \
# 0  2023-06-13 17:33:18        1         at-st         2.0         8.0
# 1  2023-06-13 17:33:17        2  tie_silencer         4.0         4.0
# 2  2023-06-13 17:33:16        3         at-at         0.0         3.0
# 3  2023-06-13 17:33:15        4  tie_silencer         6.0         1.0
# 4  2023-06-13 17:33:14        5   tie_fighter         0.0         4.0
#
#    destination_x  destination_y    homeworld
# 0              1              1  Glee Anselm
# 1              0              1    Trandosha
# 2              6              1     Corellia
# 3              6              9        Shili
# 4              9              6   Muunilinst

# %%
import pickle
loaded_model = pickle.load(open("trained_model.pkl", 'rb'))

# %%
data_for_model = troop_movements10m[["homeworld", "unit_type"]].copy()
data_for_model = pd.get_dummies(data_for_model)

# %%
predicted = loaded_model.predict(data_for_model)

# %%
troop_movements10m["predictions"] = predicted.copy()

# %%
troop_movements10m
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000             unknown         6.0
#
#          location_y  destination_x  destination_y    homeworld  predictions
# ...
